# %% [markdown]
# # Benchmark Transformation Tasks

# %% [markdown]
# ### SNAILS SQLITE Generation

# %%
from NlSqlBenchmark.snails.SnailsNlSqlBenchmark import SnailsNlSqlBenchmark
from NlSqlBenchmark.SchemaDDLGenerator import SchemaDDLGenerator

# %%
snails = SnailsNlSqlBenchmark(db_host_profile="docker", kill_container_on_exit=False)

# %%
ddl_gen = SchemaDDLGenerator()

# %%
import os
os.chdir("..")

# %%
ddl_gen.transform_benchmark_to_sqlite(
    benchmark=snails,
    db_path="./benchmarks/snails/snails_sqlite_new",
    # do_only=["SBODemoUS"]
    )
# Out:
# ./benchmarks/snails/snails_sqlite_new/SBODemoUS.sqlite
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ddl_gen.transform_benchmark_to_sqlite(
#       2     benchmark=snails,
#       3     db_path="./benchmarks/snails/snails_sqlite_new",
#       4     do_only=["SBODemoUS"]
#       5     )
#
# File c:\Users\kyle.luoma\Research Projects\SKALPEL-subsetting-evaluation\src\NlSqlBenchmark\SchemaDDLGenerator.py:32, in SchemaDDLGenerator.transform_benchmark_to_sqlite(self, benchmark, db_path, do_only)
#      30     continue
#      31 schema = benchmark.get_active_schema(db_name)
# ---> 32 self.make_sqlite_database(schema=schema, schema_dialect=benchmark.sql_dialect, db_path=db_path)
#      33 save_path = db_path + "/" + schema.database + ".sqlite"
#      34 connection = sqlite3.connect(save_path)
#
# ...
